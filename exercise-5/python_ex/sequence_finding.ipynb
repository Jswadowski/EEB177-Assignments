# %%
#import data file from CSB/unix/data 
#export csv-formatted data file to /home/eeb177-student/Desktop/eeb-177/
                                  #lab-work/exercise-5/python_ex
#columns with each unique contig
#count # of AATG in sequence
# # of times AATG appears in sequence
import csv
import re


#dna_file = open("/home/eeb177-student/Desktop/CSB/unix/data/Marra2014_data.fasta", "r")
#dna_2 = dna_file.read()  #read contents   

with open("/home/eeb177-student/Desktop/CSB/unix/data/Marra2014_data.fasta") as file:
    datalist = []
    for line in file:
        if line.startswith('>'):
            datalist.append([line.strip()[1:], ''])
        else:
            datalist[-1][1] += line.strip()
    for data in datalist:
        print(data[0], '   ', data[1].count('AATG'))



#output_file = open("/home/eeb177-student/Desktop/eeb-177/lab-work/exercise-5/python_ex/output_Marra2014_data.csv", "w")
#output_file.close()




    
        
#contig_name = contigs.search(">(\w*)\s.*", line).group(1)
#contigs.match(pattern=">", string=line)):
# Out:
# contig00001  length=527  numreads=2  gene=isogroup00001  status=it_thresh     4
# contig00002  length=551  numreads=8  gene=isogroup00001  status=it_thresh     1
# contig00003  length=541  numreads=2  gene=isogroup00001  status=it_thresh     1
# contig00004  length=291  numreads=3  gene=isogroup00001  status=it_thresh     1
# contig00005  length=580  numreads=12  gene=isogroup00001  status=it_thresh     4
# contig00006  length=3288  numreads=35  gene=isogroup00001  status=it_thresh     10
# contig00008  length=1119  numreads=10  gene=isogroup00001  status=it_thresh     3
# contig00010  length=202  numreads=4  gene=isogroup00001  status=it_thresh     0
# contig00011  length=5563  numreads=61  gene=isogroup00001  status=it_thresh     33
# contig00012  length=824  numreads=10  gene=isogroup00001  status=it_thresh     1
# contig00013  length=707  numreads=6  gene=isogroup00001  status=it_thresh     4
# contig00014  length=568  numreads=2  gene=isogroup00001  status=it_thresh     0
# ...
